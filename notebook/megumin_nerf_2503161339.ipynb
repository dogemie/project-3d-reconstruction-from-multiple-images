# %%
# !pip install pycolmap
# Out:
# Requirement already satisfied: pycolmap in /usr/local/lib/python3.11/dist-packages (3.11.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pycolmap) (1.26.4)

# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')
FOLDERNAME = 'megumin_project'
assert FOLDERNAME is not None, "[!] Enter the foldername."

import sys
sys.path.append('/content/drive/MyDrive/{}'.format(FOLDERNAME))

# Change dariectory to current folder
# %cd /content/drive/MyDrive/$FOLDERNAME
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/megumin_project

# %%
import os, sys
import numpy as np
import pycolmap
import cv2
import struct
from pathlib import Path
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import time

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# !import torch

print(torch.cuda.memory_summary(device=device, abbreviated=True))
# Out:
# /bin/bash: line 1: import: command not found
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 6            |        cudaMalloc retries: 11        |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      | 204024 KiB |  14928 MiB | 331739 MiB | 331540 MiB |
# |---------------------------------------------------------------------------|
# | Active memory         | 204024 KiB |  14928 MiB | 331739 MiB | 331540 MiB |
# |---------------------------------------------------------------------------|
# | Requested memory      | 203692 KiB |  14928 MiB | 331224 MiB | 331025 MiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   | 532480 KiB |  14962 MiB |  80546 MiB |  80026 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory | 328456 KiB |   1857 MiB | 299659 MiB | 299339 MiB |
# |---------------------------------------------------------------------------|
# | Allocations           |      63    |    1650    |  117678    |  117615    |
# |---------------------------------------------------------------------------|
# | Active allocs         |      63    |    1650    |  117678    |  117615    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |      13    |     725    |    4098    |    4085    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      31    |     570    |   58351    |   58320    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
import gc
gc.collect()
torch.cuda.empty_cache()
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
sparse_dir = Path("output/0")  # COLMAP에서 생성된 데이터가 저장된 폴더
image_dir = Path("images_no_bg")  # 실제 이미지가 저장된 폴더

# %%
reconstruction = pycolmap.Reconstruction("output/0")
print(reconstruction)
# Out:
# Reconstruction(num_cameras=193, num_images=193, num_reg_images=193, num_points3D=7161)

# %%
# 카메라 정보 가져오기
cameras = reconstruction.cameras
camera = list(cameras.values())[0]  # 첫 번째 카메라 정보 사용

# %%
# COLMAP images.bin 파일 경로
images_bin_path = "output/0"

# images.bin 파일 로드
reconstruction = pycolmap.Reconstruction()
reconstruction.read(images_bin_path)

# 첫 번째 이미지 객체 확인 (구조 분석)
image_ids = list(reconstruction.images.keys())
first_image = reconstruction.images[image_ids[0]]

# Rotation3d 객체 확인
rotation_data = first_image.cam_from_world.rotation

# Rotation3d 객체가 어떤 속성을 가지고 있는지 확인
print(dir(rotation_data))
# Out:
# ['__class__', '__copy__', '__deepcopy__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '_pybind11_conduit_v1_', 'angle', 'angle_to', 'inverse', 'matrix', 'mergedict', 'norm', 'normalize', 'quat', 'summary', 'todict']

# %%
# Focal Length 및 해상도 가져오기
focal = camera.focal_length
H, W = camera.height, camera.width
print(f"Camera Info: Focal Length = {focal}, Image Size = ({W}, {H})")

# 2️⃣ 이미지 및 포즈 데이터 가져오기 (images.bin)
image_data = reconstruction.images
sorted_images = sorted(image_data.items(), key=lambda x: x[1].name)
# 3️⃣ 이미지 배열 및 카메라 포즈 배열 만들기
image_list = []
pose_list = []
print(f"Total images in COLMAP reconstruction: {len(image_data)}")
# Out:
# Camera Info: Focal Length = 819.4829121182896, Image Size = (720, 720)
# Total images in COLMAP reconstruction: 193

# %%
# 2️⃣ 이미지 및 포즈 데이터 가져오기 (images.bin)
image_data = reconstruction.images
sorted_images = sorted(image_data.items(), key=lambda x: x[1].name)
print(f"Total images in COLMAP reconstruction: {len(image_data)}")
# Out:
# Total images in COLMAP reconstruction: 193

# %%
def qvec_to_rotmat(qvec):
    """
    Convert a quaternion (w, x, y, z) to a 3x3 rotation matrix.

    Parameters:
    qvec (array-like): Quaternion in the form (w, x, y, z).

    Returns:
    np.ndarray: 3x3 rotation matrix.
    """
    w, x, y, z = qvec
    R = np.array([
        [1 - 2 * (y * y + z * z), 2 * (x * y - z * w), 2 * (x * z + y * w)],
        [2 * (x * y + z * w), 1 - 2 * (x * x + z * z), 2 * (y * z - x * w)],
        [2 * (x * z - y * w), 2 * (y * z + x * w), 1 - 2 * (x * x + y * y)]
    ])
    return R

# %%
# 3️⃣ 이미지 배열 및 카메라 포즈 배열 만들기
image_list = []
pose_list = []

for img_id, image in sorted_images:
    img_path = image_dir / image.name
    img = cv2.imread(str(img_path))  # 이미지 로드
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # BGR → RGB 변환
    image_list.append(img)

    # COLMAP의 카메라 포즈 변환 (Rigid3d → 4x4 변환 행렬)
    pose = np.eye(4)  # 4x4 단위 행렬 생성

    # 🔹 Quaternion (w, x, y, z) → 3x3 회전 행렬 변환
    qvec = np.array(image.cam_from_world.rotation.quat)
    pose[:3, :3] = qvec_to_rotmat(qvec)  # Quaternion을 3x3 회전 행렬로 변환

    # 🔹 Translation 벡터 변환 (COLMAP은 camera-to-world 변환이므로 부호 반전)
    pose[:3, 3] = -np.array(image.cam_from_world.translation)

    # 🔹 COLMAP 좌표계를 OpenGL 좌표계로 변환 (NeRF 호환)
    pose = np.diag([1, -1, -1, 1]) @ pose  # YZ 축 반전 (COLMAP → OpenGL)

    #print(f"Image {img_id} pose matrix:\n{pose}\n")  # 변환된 행렬 출력
    pose_list.append(pose)
# Out:
# Image 1 pose matrix:
# [[-0.98773642  0.06164084 -0.14344747  1.01444728]
#  [ 0.03764048  0.98567942  0.1643754  -1.07931339]
#  [ 0.15152546  0.15696014 -0.97591165  2.96656552]
#  [ 0.          0.          0.          1.        ]]
#
# Image 5 pose matrix:
# [[-0.99387441  0.05025463 -0.09842827  1.07994597]
#  [ 0.03825207  0.99200739  0.12024191 -1.1126834 ]
#  [ 0.10368428  0.11574027 -0.98785311  3.11026362]
#  [ 0.          0.          0.          1.        ]]
#
# Image 4 pose matrix:
# [[-0.99793839  0.03944291 -0.05062839  1.09989953]
#  [ 0.03580488  0.9968437   0.07085658 -1.13510671]
#  [ 0.05326338  0.06889776 -0.99620084  3.27334156]
#  [ 0.          0.          0.          1.        ]]
#
# Image 2 pose matrix:
# [[-0.99960911  0.0252997   0.01189792  1.08065886]
#  [ 0.02536368  0.99966446  0.00525754 -1.17623374]
#  [-0.01176091  0.00555726 -0.9999154   3.42362906]
#  [ 0.          0.          0.          1.        ]]
#
# Image 3 pose matrix:
# [[-0.99711388  0.01190225  0.07498161  1.04457082]
#  [ 0.0074635   0.9982181  -0.05920233 -1.20315696]
#  [-0.07555264 -0.05847184 -0.99542596  3.37547829]
#  [ 0.          0.          0.          1.        ]]
#
# Image 8 pose matrix:
# [[-9.92527121e-01  8.80835038e-04  1.22021056e-01  1.01502723e+00]
#  [-1.23549279e-02  9.94109703e-01 -1.07671971e-01 -1.18063983e+00]
#  [-1.21397157e-01 -1.08374913e-01 -9.86669959e-01  3.29087176e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#
# Image 7 pose matrix:
# [[-0.9829263  -0.00876513  0.18379081  1.02095484]
#  [-0.04093661  0.98424734 -0.17199234 -1.08601008]
#  [-0.17938808 -0.17657957 -0.96780141  3.11637424]
#  [ 0.          0.          0.          1.        ]]
#
# Image 6 pose matrix:
# [[-0.96765349 -0.00653607  0.25219835  1.0120102 ]
#  [-0.06958221  0.96780397 -0.24189625 -0.97777147]
#  [-0.24249751 -0.25162026 -0.93695368  3.06989442]
#  [ 0.          0.          0.          1.        ]]
#
# Image 9 pose matrix:
# [[-0.94735439  0.00334956  0.3201694   0.9972022 ]
#  [-0.10455487  0.94189434 -0.31922302 -0.93148565]
#  [-0.302635   -0.3358926  -0.89195752  3.16284534]
#  [ 0.          0.          0.          1.        ]]
#
# Image 11 pose matrix:
# [[-0.9264966   0.01185755  0.37611627  0.98412512]
#  [-0.13980503  0.91711656 -0.37329849 -0.98033653]
#  [-0.34936886 -0.39844273 -0.84804763  3.10387442]
#  [ 0.          0.          0.          1.        ]]
#
# Image 10 pose matrix:
# [[-0.8930499   0.02784207  0.44909542  0.94236958]
#  [-0.19289893  0.87802357 -0.43802354 -1.10659234]
#  [-0.40651184 -0.4778069  -0.77874815  3.03209044]
#  [ 0.          0.          0.          1.        ]]
#
# Image 12 pose matrix:
# [[-0.85692087  0.05669141  0.5123209   0.89033468]
#  [-0.24090898  0.83464479 -0.49530893 -1.28568125]
#  [-0.45568573 -0.54786327 -0.70156707  3.08895323]
#  [ 0.          0.          0.          1.        ]]
#
# Image 13 pose matrix:
# [[-0.82043506  0.09356264  0.56403222  0.78707138]
#  [-0.2870285   0.785791   -0.54785687 -1.44759375]
#  [-0.49447037 -0.6113743  -0.61783534  3.13027678]
#  [ 0.          0.          0.          1.        ]]
#
# Image 14 pose matrix:
# [[-0.79265519  0.12563446  0.59658506  0.70871556]
#  [-0.32253833  0.74397127 -0.5852143  -1.58529194]
#  [-0.51736523 -0.6562947  -0.54919076  3.18428915]
#  [ 0.          0.          0.          1.        ]]
#
# Image 16 pose matrix:
# [[-0.75480942  0.1785383   0.63117892  0.59530826]
#  [-0.36308305  0.68766628 -0.62871757 -1.65817647]
#  [-0.54629062 -0.70373231 -0.45423276  3.22701346]
#  [ 0.          0.          0.          1.        ]]
#
# Image 15 pose matrix:
# [[-0.7186078   0.22967962  0.65639173  0.51829452]
#  [-0.40616221  0.62754307 -0.6642454  -1.6694704 ]
#  [-0.56447771 -0.74393345 -0.35767016  3.12551138]
#  [ 0.          0.          0.          1.        ]]
#
# Image 17 pose matrix:
# [[-0.6837955   0.28505278  0.67169087  0.51209198]
#  [-0.44673851  0.56429011 -0.69426319 -1.67765994]
#  [-0.57693017 -0.77480422 -0.25851498  3.2536762 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 23 pose matrix:
# [[-0.65395378  0.33048627  0.68053161  0.45780398]
#  [-0.47604624  0.51936703 -0.70967448 -1.68190588]
#  [-0.58798336 -0.78805882 -0.18231529  3.27542541]
#  [ 0.          0.          0.          1.        ]]
#
# Image 18 pose matrix:
# [[-0.61590687  0.38941793  0.6848448   0.32189722]
#  [-0.51734566  0.45567152 -0.72437348 -1.74168826]
#  [-0.59414829 -0.80044809 -0.07918754  3.29339374]
#  [ 0.          0.          0.          1.        ]]
#
# Image 19 pose matrix:
# [[-0.57995678  0.44127183  0.68478413  0.19720965]
#  [-0.55797294  0.39729739 -0.72857462 -1.81623731]
#  [-0.59356241 -0.80463281  0.01580243  3.36362153]
#  [ 0.          0.          0.          1.        ]]
#
# Image 24 pose matrix:
# [[-0.54733948  0.49163891  0.67728183  0.07808391]
#  [-0.59519643  0.34025069 -0.72799085 -1.91118322]
#  [-0.58835424 -0.80157386  0.10638909  3.3959042 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 20 pose matrix:
# [[-0.52518486  0.53044218  0.66544117 -0.00427534]
#  [-0.61927928  0.29810374 -0.72637961 -1.99111714]
#  [-0.58367289 -0.7935775   0.17193228  3.35739438]
#  [ 0.          0.          0.          1.        ]]
#
# Image 21 pose matrix:
# [[-0.49837584  0.58238041  0.64222627 -0.07418548]
#  [-0.65032099  0.23875559 -0.7211646  -2.07305427]
#  [-0.57332725 -0.77706424  0.25974419  3.32651184]
#  [ 0.          0.          0.          1.        ]]
#
# Image 22 pose matrix:
# [[-0.4728466   0.63198474  0.61401253 -0.16020886]
#  [-0.67834867  0.18365099 -0.71141788 -2.1017462 ]
#  [-0.56236925 -0.7529061   0.34186726  3.34209072]
#  [ 0.          0.          0.          1.        ]]
#
# Image 27 pose matrix:
# [[-0.44738142  0.67850895  0.58264523 -0.36226821]
#  [-0.70858582  0.12857326 -0.69381198 -2.05399666]
#  [-0.54567023 -0.72325273  0.42326053  3.3602769 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 26 pose matrix:
# [[-0.43335337  0.70826217  0.55728768 -0.49426561]
#  [-0.73202095  0.08407126 -0.67607496 -2.01262191]
#  [-0.52569019 -0.70092562  0.48203019  3.23369548]
#  [ 0.          0.          0.          1.        ]]
#
# Image 28 pose matrix:
# [[-0.4107369   0.74836581  0.52081072 -0.6569754 ]
#  [-0.76203754  0.03185188 -0.64674898 -1.91135532]
#  [-0.50059363 -0.66252099  0.5572001   3.16764303]
#  [ 0.          0.          0.          1.        ]]
#
# Image 25 pose matrix:
# [[-0.39136912  0.78490118  0.48037521 -0.77083835]
#  [-0.79037051 -0.01934189 -0.61232373 -1.86034884]
#  [-0.47132226 -0.619319    0.62793256  3.16270801]
#  [ 0.          0.          0.          1.        ]]
#
# Image 32 pose matrix:
# [[-0.37434412  0.81822373  0.43632146 -0.87857352]
#  [-0.8178689  -0.06959747 -0.57118005 -1.89710289]
#  [-0.4369862  -0.57067164  0.69525314  3.11291597]
#  [ 0.          0.          0.          1.        ]]
#
# Image 36 pose matrix:
# [[-0.36680743  0.83966922  0.40050956 -0.90221748]
#  [-0.83377299 -0.10576171 -0.54188288 -1.94864194]
#  [-0.4126438  -0.53270072  0.7388877   2.96698873]
#  [ 0.          0.          0.          1.        ]]
#
# Image 30 pose matrix:
# [[-0.34801266  0.87382003  0.33959644 -0.89917971]
#  [-0.85832143 -0.15129236 -0.49030086 -1.98426636]
#  [-0.37705637 -0.46211381  0.80267012  3.10381289]
#  [ 0.          0.          0.          1.        ]]
#
# Image 29 pose matrix:
# [[-0.33366453  0.90389277  0.26766741 -0.9308201 ]
#  [-0.87884    -0.19554006 -0.43520609 -1.93458409]
#  [-0.34103994 -0.38044966  0.8596219   3.26412239]
#  [ 0.          0.          0.          1.        ]]
#
# Image 31 pose matrix:
# [[-0.32400662  0.92609979  0.19328451 -0.99070041]
#  [-0.89420732 -0.2330836  -0.3821849  -1.77685863]
#  [-0.30888991 -0.29666686  0.90364584  3.19981741]
#  [ 0.          0.          0.          1.        ]]
#
# Image 35 pose matrix:
# [[-0.31217978  0.9400578   0.13724111 -1.0826575 ]
#  [-0.90840689 -0.25308518 -0.33278342 -1.57744201]
#  [-0.27810196 -0.22855902  0.93296306  3.07972084]
#  [ 0.          0.          0.          1.        ]]
#
# Image 33 pose matrix:
# [[-0.2974782   0.95292836  0.0586026  -1.08103496]
#  [-0.92668905 -0.2734303  -0.25784351 -1.29367916]
#  [-0.22968266 -0.13100921  0.96440783  2.92862594]
#  [ 0.          0.          0.          1.        ]]
#
# Image 34 pose matrix:
# [[-0.28623375  0.95796813 -0.0191649  -1.06151209]
#  [-0.9430129  -0.28519496 -0.17143658 -1.0838832 ]
#  [-0.16969652 -0.03099819  0.98500873  2.86131962]
#  [ 0.          0.          0.          1.        ]]
#
# Image 37 pose matrix:
# [[-0.27697226  0.95657002 -0.09088544 -1.06019278]
#  [-0.95515363 -0.28439696 -0.08246153 -1.04357245]
#  [-0.10472777  0.06397     0.9924414   2.60926254]
#  [ 0.          0.          0.          1.        ]]
#
# Image 42 pose matrix:
# [[-0.27361824  0.95122016 -0.14252464 -1.12372548]
#  [-0.96020133 -0.27877874 -0.01719953 -1.0571344 ]
#  [-0.05609338  0.13214625  0.9896418   2.45779967]
#  [ 0.          0.          0.          1.        ]]
#
# Image 40 pose matrix:
# [[-0.27345155  0.938309   -0.21166124 -1.22923375]
#  [-0.96185115 -0.26487227  0.06844738 -1.04053931]
#  [ 0.0081616   0.22230365  0.97494332  2.3313855 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 45 pose matrix:
# [[-0.2554458   0.92464776 -0.28244283 -1.30093145]
#  [-0.9639165  -0.22093137  0.14850694 -0.98380454]
#  [ 0.07491612  0.31018678  0.94771923  2.25948022]
#  [ 0.          0.          0.          1.        ]]
#
# Image 38 pose matrix:
# [[-0.24292789  0.90623058 -0.34602338 -1.42716793]
#  [-0.9602498  -0.17409332  0.21820136 -0.9505163 ]
#  [ 0.13750039  0.38527608  0.91249986  2.3389695 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 43 pose matrix:
# [[-0.23629313  0.89055369 -0.38868969 -1.57615967]
#  [-0.9545776  -0.13802766  0.26406434 -0.9192783 ]
#  [ 0.18151354  0.43343106  0.88271759  2.33496949]
#  [ 0.          0.          0.          1.        ]]
#
# Image 41 pose matrix:
# [[-0.23659377  0.87016062 -0.43225442 -1.75611317]
#  [-0.93972988 -0.09191276  0.32933236 -0.80395216]
#  [ 0.24684235  0.48412038  0.83946192  2.31645136]
#  [ 0.          0.          0.          1.        ]]
#
# Image 39 pose matrix:
# [[-0.26046465  0.84786026 -0.46183454 -1.85724503]
#  [-0.90678925 -0.05058756  0.41853812 -0.67233789]
#  [ 0.33149876  0.52780098  0.78200684  2.26349946]
#  [ 0.          0.          0.          1.        ]]
#
# Image 48 pose matrix:
# [[-0.27003384  0.82608972 -0.49462865 -1.86531151]
#  [-0.87257371  0.00722269  0.48842907 -0.63526835]
#  [ 0.40705878  0.56349233  0.7188738   2.16762851]
#  [ 0.          0.          0.          1.        ]]
#
# Image 46 pose matrix:
# [[-0.25286872  0.81400283 -0.52293098 -1.79907939]
#  [-0.86189347  0.05602379  0.5039851  -0.66569916]
#  [ 0.43954187  0.57815286  0.68741706  2.24953626]
#  [ 0.          0.          0.          1.        ]]
#
# Image 44 pose matrix:
# [[-0.23573261  0.80106699 -0.55020161 -1.61679818]
#  [-0.83940321  0.11746512  0.53066391 -0.74581673]
#  [ 0.48972684  0.58693579  0.64472785  2.14198932]
#  [ 0.          0.          0.          1.        ]]
#
# Image 47 pose matrix:
# [[-0.20653041  0.78923629 -0.57831761 -1.42294755]
#  [-0.81093865  0.19264488  0.55250924 -0.82057013]
#  [ 0.54747027  0.58309006  0.60023519  2.17809855]
#  [ 0.          0.          0.          1.        ]]
#
# Image 49 pose matrix:
# [[-0.17507144  0.78437504 -0.59506788 -1.26897579]
#  [-0.7778492   0.26033061  0.57199527 -1.04702559]
#  [ 0.6035732   0.56301311  0.56454904  2.13151273]
#  [ 0.          0.          0.          1.        ]]
#
# Image 51 pose matrix:
# [[-0.15713771  0.77731059 -0.60917648 -1.22776574]
#  [-0.74287769  0.31340521  0.59153183 -1.24765521]
#  [ 0.65072304  0.54549557  0.52819892  2.07313435]
#  [ 0.          0.          0.          1.        ]]
#
# Image 52 pose matrix:
# [[-0.14120108  0.76978298 -0.62249211 -1.34922691]
#  [-0.69076817  0.37381426  0.61895253 -1.4923225 ]
#  [ 0.70915555  0.5173945   0.4789586   1.94460833]
#  [ 0.          0.          0.          1.        ]]
#
# Image 50 pose matrix:
# [[-0.12839079  0.76033958 -0.63670992 -1.49072414]
#  [-0.63901054  0.4275526   0.63942498 -1.72567897]
#  [ 0.75840711  0.48896063  0.43097119  1.94512742]
#  [ 0.          0.          0.          1.        ]]
#
# Image 54 pose matrix:
# [[-0.11153475  0.7533232  -0.64812357 -1.56942789]
#  [-0.59749577  0.47030824  0.64946821 -1.88719821]
#  [ 0.79407733  0.45968937  0.39765171  1.9908456 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 55 pose matrix:
# [[-0.08894169  0.74796594 -0.65775096 -1.56863019]
#  [-0.5773646   0.49938999  0.64595647 -1.98802802]
#  [ 0.81162769  0.43721458  0.38743246  2.14564204]
#  [ 0.          0.          0.          1.        ]]
#
# Image 53 pose matrix:
# [[-0.05315341  0.73887116 -0.67174707 -1.51100017]
#  [-0.56727048  0.53127371  0.62924753 -2.05336013]
#  [ 0.8218144   0.41450893  0.39090079  2.30831673]
#  [ 0.          0.          0.          1.        ]]
#
# Image 56 pose matrix:
# [[-0.02025281  0.72975147 -0.68341248 -1.4270875 ]
#  [-0.55907545  0.55842587  0.61285821 -2.05855374]
#  [ 0.82886939  0.39449125  0.39667644  2.46820327]
#  [ 0.          0.          0.          1.        ]]
#
# Image 58 pose matrix:
# [[ 0.00379748  0.72113301 -0.69278623 -1.31434689]
#  [-0.54795629  0.58102349  0.60179367 -2.02919509]
#  [ 0.83649835  0.37733127  0.39735579  2.69745864]
#  [ 0.          0.          0.          1.        ]]
#
# Image 57 pose matrix:
# [[ 0.01230547  0.71440566 -0.69962356 -1.20802121]
#  [-0.54078506  0.59327688  0.59630031 -2.01446618]
#  [ 0.8410708   0.37100822  0.39364046  2.89018633]
#  [ 0.          0.          0.          1.        ]]
#
# Image 60 pose matrix:
# [[ 0.01085623  0.70555829 -0.70856872 -1.07364151]
#  [-0.52255265  0.60815597  0.59756594 -2.08787375]
#  [ 0.8525379   0.36377715  0.37529364  3.07170525]
#  [ 0.          0.          0.          1.        ]]
#
# Image 59 pose matrix:
# [[-0.00597175  0.69972143 -0.71439083 -1.05555094]
#  [-0.49366303  0.61921695  0.61062851 -2.11747706]
#  [ 0.86963277  0.35631486  0.3417288   3.22818146]
#  [ 0.          0.          0.          1.        ]]
#
# Image 61 pose matrix:
# [[-0.03931618  0.6943942  -0.71851996 -1.07530065]
#  [-0.4561842   0.62729144  0.63119048 -2.05992003]
#  [ 0.88901643  0.35259345  0.29210896  3.34489015]
#  [ 0.          0.          0.          1.        ]]
#
# Image 62 pose matrix:
# [[-0.07836743  0.68903975 -0.72047399 -1.16092643]
#  [-0.41339206  0.63517406  0.65242695 -1.98008795]
#  [ 0.90717449  0.34896725  0.2350666   3.36011061]
#  [ 0.          0.          0.          1.        ]]
#
# Image 63 pose matrix:
# [[-0.17081995  0.67758887 -0.71532781 -1.47630993]
#  [-0.32027974  0.64838727  0.69066261 -1.86681972]
#  [ 0.93179474  0.34708395  0.10626051  3.30195119]
#  [ 0.          0.          0.          1.        ]]
#
# Image 65 pose matrix:
# [[-0.23859642  0.66701676 -0.70580478 -1.68309489]
#  [-0.25971313  0.6564944   0.70821197 -1.80910809]
#  [ 0.93574614  0.35228361  0.0165958   3.19839953]
#  [ 0.          0.          0.          1.        ]]
#
# Image 64 pose matrix:
# [[-0.25046428  0.65664164 -0.71139961 -1.43929405]
#  [-0.27359787  0.65685821  0.70262472 -1.77743282]
#  [ 0.92866132  0.37061981  0.01513624  3.24284389]
#  [ 0.          0.          0.          1.        ]]
#
# Image 66 pose matrix:
# [[-0.25360792  0.65061093 -0.71581314 -1.12919712]
#  [-0.27832472  0.65963175  0.69815564 -1.72245215]
#  [ 0.92640076  0.37628629  0.01379327  3.03396693]
#  [ 0.          0.          0.          1.        ]]
#
# Image 68 pose matrix:
# [[-0.26734156  0.64041156 -0.72000106 -0.72786085]
#  [-0.28422138  0.66154845  0.69395378 -1.67975243]
#  [ 0.92073161  0.39016238  0.00515927  2.9499682 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 67 pose matrix:
# [[-0.29372648  0.63154836 -0.71754542 -0.43590944]
#  [-0.28222749  0.6598955   0.69633726 -1.68242894]
#  [ 0.91327564  0.40704373 -0.01558848  2.92608841]
#  [ 0.          0.          0.          1.        ]]
#
# Image 70 pose matrix:
# [[-0.33216246  0.62284455 -0.70833097 -0.34339467]
#  [-0.25838219  0.66215848  0.7034094  -1.74109586]
#  [ 0.90714207  0.41666631 -0.05901225  2.93558404]
#  [ 0.          0.          0.          1.        ]]
#
# Image 72 pose matrix:
# [[-0.36366043  0.61406036 -0.70048624 -0.31392219]
#  [-0.23933352  0.6651392   0.70732546 -1.78743167]
#  [ 0.90026138  0.42487612 -0.09491958  2.8980382 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 69 pose matrix:
# [[-0.3997034   0.60294062 -0.6904345  -0.30126359]
#  [-0.21956357  0.66831714  0.71073485 -1.85907826]
#  [ 0.88996013  0.4356774  -0.13474484  2.97829275]
#  [ 0.          0.          0.          1.        ]]
#
# Image 73 pose matrix:
# [[-0.4317963   0.59238063 -0.68017435 -0.29763319]
#  [-0.19862916  0.67313458  0.71234563 -1.87791459]
#  [ 0.87982862  0.44269067 -0.17299295  3.01547178]
#  [ 0.          0.          0.          1.        ]]
#
# Image 71 pose matrix:
# [[-0.46282876  0.57909328 -0.67114865 -0.27051797]
#  [-0.18225138  0.67878367  0.71136289 -1.90782355]
#  [ 0.86751022  0.45155697 -0.20862006  2.98579243]
#  [ 0.          0.          0.          1.        ]]
#
# Image 76 pose matrix:
# [[-0.48326819  0.56930613 -0.66508826 -0.2738314 ]
#  [-0.16952055  0.6844613   0.70906665 -1.9235382 ]
#  [ 0.85890316  0.45541548 -0.23426929  2.97516961]
#  [ 0.          0.          0.          1.        ]]
#
# Image 74 pose matrix:
# [[-0.50708613  0.55641787 -0.65822702 -0.21591827]
#  [-0.15534892  0.69218558  0.70480198 -1.90940097]
#  [ 0.84777967  0.45965017 -0.26455879  2.92322465]
#  [ 0.          0.          0.          1.        ]]
#
# Image 78 pose matrix:
# [[-0.52775079  0.54203848 -0.65396742 -0.08376136]
#  [-0.14703631  0.69999542  0.69884672 -1.86175491]
#  [ 0.83657601  0.46497387 -0.2897238   2.80003482]
#  [ 0.          0.          0.          1.        ]]
#
# Image 80 pose matrix:
# [[-0.54739444  0.52547276 -0.65133533  0.12225327]
#  [-0.14434494  0.70734732  0.69197132 -1.81796545]
#  [ 0.82433237  0.47279821 -0.31134866  2.68386758]
#  [ 0.          0.          0.          1.        ]]
#
# Image 75 pose matrix:
# [[-0.56209289  0.51260771 -0.64906465  0.31427294]
#  [-0.13972565  0.71463744  0.68539775 -1.81913787]
#  [ 0.81518607  0.47594818 -0.33006818  2.6366715 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 79 pose matrix:
# [[-0.58873927  0.49097144 -0.6421317   0.51389747]
#  [-0.12932786  0.72695236  0.67439941 -1.7952059 ]
#  [ 0.79791001  0.48009093 -0.36448911  2.54224049]
#  [ 0.          0.          0.          1.        ]]
#
# Image 77 pose matrix:
# [[-0.63089377  0.47273335 -0.61522047  0.59630858]
#  [-0.09670505  0.73884804  0.66689707 -1.69189012]
#  [ 0.76981893  0.48023614 -0.42041893  2.57086757]
#  [ 0.          0.          0.          1.        ]]
#
# Image 83 pose matrix:
# [[-0.68511565  0.4566637  -0.56751635  0.54002994]
#  [-0.04007362  0.75428219  0.65532624 -1.62854722]
#  [ 0.72733118  0.4717167  -0.49847037  2.50913575]
#  [ 0.          0.          0.          1.        ]]
#
# Image 82 pose matrix:
# [[-0.71722258  0.44055545 -0.53990988  0.52917893]
#  [-0.01220079  0.76673499  0.64184779 -1.61347771]
#  [ 0.69673734  0.46693506 -0.54454452  2.46303629]
#  [ 0.          0.          0.          1.        ]]
#
# Image 81 pose matrix:
# [[-0.74342893  0.42432406 -0.51697438  0.62657113]
#  [ 0.01146297  0.78094114  0.62449943 -1.6671275 ]
#  [ 0.6687167   0.45834488 -0.58543825  2.46049085]
#  [ 0.          0.          0.          1.        ]]
#
# Image 88 pose matrix:
# [[-0.76899362  0.4040154  -0.4953992   0.7382398 ]
#  [ 0.02834512  0.79574947  0.60496226 -1.6766466 ]
#  [ 0.63862772  0.45116997 -0.62337813  2.43440467]
#  [ 0.          0.          0.          1.        ]]
#
# Image 90 pose matrix:
# [[-0.79556548  0.38529377 -0.46757276  0.81390284]
#  [ 0.05440146  0.81405138  0.57823942 -1.64885046]
#  [ 0.60342029  0.43459068 -0.66859172  2.43040023]
#  [ 0.          0.          0.          1.        ]]
#
# Image 84 pose matrix:
# [[-0.81867906  0.36693753 -0.44172553  0.81855656]
#  [ 0.07555835  0.83136324  0.55056889 -1.6727171 ]
#  [ 0.56925876  0.41736317 -0.70834487  2.4150633 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 85 pose matrix:
# [[-0.84959088  0.34394414 -0.39987219  0.78683559]
#  [ 0.10628913  0.8542256   0.50892165 -1.70850058]
#  [ 0.51662168  0.38987313 -0.7622998   2.38346021]
#  [ 0.          0.          0.          1.        ]]
#
# Image 87 pose matrix:
# [[-0.87913706  0.32386083 -0.34961721  0.7753774 ]
#  [ 0.13620962  0.87376471  0.46688561 -1.68042809]
#  [ 0.45668914  0.36283521 -0.8122719   2.32008295]
#  [ 0.          0.          0.          1.        ]]
#
# Image 86 pose matrix:
# [[-0.90334249  0.31280683 -0.29346929  0.83838514]
#  [ 0.16920622  0.888607    0.42631778 -1.66019459]
#  [ 0.39413398  0.33545414 -0.85564533  2.28029856]
#  [ 0.          0.          0.          1.        ]]
#
# Image 89 pose matrix:
# [[-0.91708338  0.31107134 -0.24938463  0.86148261]
#  [ 0.19746458  0.89778035  0.3936981  -1.64541634]
#  [ 0.34636082  0.31180935 -0.88476501  2.25141906]
#  [ 0.          0.          0.          1.        ]]
#
# Image 91 pose matrix:
# [[-0.93327926  0.3040556  -0.19115442  0.90455851]
#  [ 0.22587742  0.91071488  0.34580024 -1.53390553]
#  [ 0.27922968  0.27955072 -0.9186306   2.31746554]
#  [ 0.          0.          0.          1.        ]]
#
# Image 93 pose matrix:
# [[-0.94286555  0.30300571 -0.1385355   0.9551228 ]
#  [ 0.25267003  0.92133026  0.29547995 -1.31646123]
#  [ 0.21716906  0.2435941  -0.94525103  2.35645495]
#  [ 0.          0.          0.          1.        ]]
#
# Image 92 pose matrix:
# [[-0.94995382  0.30208456 -0.07957795  0.99702219]
#  [ 0.27773952  0.9333285   0.22750533 -1.26563102]
#  [ 0.14299822  0.19401762 -0.9705198   2.49442928]
#  [ 0.          0.          0.          1.        ]]
#
# Image 94 pose matrix:
# [[-0.95294158  0.30070252 -0.03847526  1.00433006]
#  [ 0.28959251  0.94048631  0.17782483 -1.37666552]
#  [ 0.08965783  0.15831453 -0.98330971  2.65067509]
#  [ 0.          0.          0.          1.        ]]
#
# Image 97 pose matrix:
# [[-0.95430544  0.29834072  0.01714472  1.0060303 ]
#  [ 0.29833541  0.94783801  0.11224566 -1.57755571]
#  [ 0.01723703  0.11223152 -0.99353257  2.87738901]
#  [ 0.          0.          0.          1.        ]]
#
# Image 95 pose matrix:
# [[-0.95208669  0.29752402  0.07078409  1.0575291 ]
#  [ 0.3015472   0.95185962  0.05506864 -1.71651476]
#  [-0.05099227  0.07377486 -0.99597041  3.07608155]
#  [ 0.          0.          0.          1.        ]]
#
# Image 96 pose matrix:
# [[-9.45014018e-01  3.01981294e-01  1.25522124e-01  1.05793623e+00]
#  [ 3.04101546e-01  9.52636659e-01 -2.37589230e-03 -1.80231822e+00]
#  [-1.20294452e-01  3.59262204e-02 -9.92087976e-01  3.24871861e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#
# Image 98 pose matrix:
# [[-0.93731435  0.30237899  0.17323037  1.04905192]
#  [ 0.2985869   0.95316522 -0.04818641 -1.76339989]
#  [-0.17968772  0.00655851 -0.98370184  3.27847013]
#  [ 0.          0.          0.          1.        ]]
#
# Image 100 pose matrix:
# [[-0.92151074  0.30412579  0.24150665  1.12417959]
#  [ 0.28544149  0.95208609 -0.10979632 -1.73517824]
#  [-0.26332701 -0.03224247 -0.96416768  3.45255125]
#  [ 0.          0.          0.          1.        ]]
#
# Image 104 pose matrix:
# [[-0.89610676  0.30694215  0.32059194  1.16747955]
#  [ 0.26544422  0.94952804 -0.16714026 -1.75134926]
#  [-0.35571343 -0.06467624 -0.93235452  3.49417025]
#  [ 0.          0.          0.          1.        ]]
#
# Image 99 pose matrix:
# [[-0.85812861  0.31001175  0.40927741  1.07659955]
#  [ 0.23463175  0.94581329 -0.22446638 -1.81561779]
#  [-0.45668723 -0.09659155 -0.88436805  3.61305219]
#  [ 0.          0.          0.          1.        ]]
#
# Image 101 pose matrix:
# [[-0.83567333  0.31548739  0.44957513  1.02876369]
#  [ 0.21789557  0.94182702 -0.25589722 -1.83754354]
#  [-0.50415435 -0.11588606 -0.85580302  3.6541428 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 102 pose matrix:
# [[-0.81720194  0.32550892  0.47563109  1.05686929]
#  [ 0.20526816  0.93550853 -0.28755656 -1.87518522]
#  [-0.53855916 -0.13735986 -0.831316    3.65363339]
#  [ 0.          0.          0.          1.        ]]
#
# Image 103 pose matrix:
# [[-0.80142557  0.33171656  0.49767578  1.13231518]
#  [ 0.18793568  0.92962426 -0.31698408 -1.90474699]
#  [-0.56780035 -0.16050811 -0.80736603  3.77758941]
#  [ 0.          0.          0.          1.        ]]
#
# Image 109 pose matrix:
# [[-0.78144531  0.34210635  0.52182992  1.20053123]
#  [ 0.17302841  0.92231169 -0.34554639 -1.97677528]
#  [-0.59950345 -0.17973421 -0.77993027  3.90292056]
#  [ 0.          0.          0.          1.        ]]
#
# Image 108 pose matrix:
# [[-0.76668758  0.3494774   0.53856819  1.22462092]
#  [ 0.16254843  0.91719612 -0.36377093 -1.9851719 ]
#  [-0.62110238 -0.19135524 -0.76000987  3.98463466]
#  [ 0.          0.          0.          1.        ]]
#
# Image 105 pose matrix:
# [[-0.74700324  0.35821408  0.56006145  1.23808771]
#  [ 0.14627378  0.91033888 -0.38715255 -2.02388744]
#  [-0.64852921 -0.2072819  -0.73242342  4.13350752]
#  [ 0.          0.          0.          1.        ]]
#
# Image 106 pose matrix:
# [[-0.72727175  0.36662221  0.5802275   1.27195059]
#  [ 0.12922251  0.90340465 -0.40885398 -2.04115197]
#  [-0.67407518 -0.2223695  -0.70439653  4.3379368 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 112 pose matrix:
# [[-0.70573805  0.37736374  0.59960855  1.33317737]
#  [ 0.10821464  0.89382577 -0.43516098 -2.03650554]
#  [-0.70015955 -0.24222324 -0.67164314  4.54944087]
#  [ 0.          0.          0.          1.        ]]
#
# Image 107 pose matrix:
# [[-0.69057601  0.385403    0.61202067  1.40953499]
#  [ 0.09248481  0.88630607 -0.45377099 -2.05673339]
#  [-0.71732234 -0.25676074 -0.64770563  4.68339695]
#  [ 0.          0.          0.          1.        ]]
#
# Image 111 pose matrix:
# [[-0.66252548  0.39856499  0.63419708  1.48577326]
#  [ 0.06227712  0.87305941 -0.48362054 -2.15869259]
#  [-0.74644595 -0.28091496 -0.60324558  4.82666779]
#  [ 0.          0.          0.          1.        ]]
#
# Image 113 pose matrix:
# [[-0.63007643  0.41404656  0.65693922  1.51309687]
#  [ 0.03171681  0.85900583 -0.51098241 -2.24535937]
#  [-0.77588513 -0.30112196 -0.55437156  4.82209232]
#  [ 0.          0.          0.          1.        ]]
#
# Image 115 pose matrix:
# [[-0.59005624  0.42831287  0.68438419  1.51225528]
#  [-0.00958844  0.8439019  -0.53641182 -2.33274516]
#  [-0.80730521 -0.32307532 -0.49384273  4.8068369 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 114 pose matrix:
# [[-0.55285261  0.43961024  0.70788193  1.42200028]
#  [-0.04617371  0.83204658 -0.55278068 -2.3399807 ]
#  [-0.83199878 -0.33829178 -0.43970069  4.85915207]
#  [ 0.          0.          0.          1.        ]]
#
# Image 110 pose matrix:
# [[-0.4997573   0.45768463  0.73536891  1.2193356 ]
#  [-0.09795736  0.81368186 -0.57299755 -2.32442328]
#  [-0.86060851 -0.3583945  -0.36180987  4.92170697]
#  [ 0.          0.          0.          1.        ]]
#
# Image 119 pose matrix:
# [[-0.44516155  0.47795909  0.75722276  1.01334473]
#  [-0.14814459  0.79466961 -0.58868785 -2.35845695]
#  [-0.88311062 -0.37423965 -0.28294931  5.00471458]
#  [ 0.          0.          0.          1.        ]]
#
# Image 116 pose matrix:
# [[-0.39229726  0.49940323  0.77246312  0.90236593]
#  [-0.20141433  0.77276431 -0.6018867  -2.43999385]
#  [-0.89751609 -0.39170364 -0.20256636  5.07622338]
#  [ 0.          0.          0.          1.        ]]
#
# Image 117 pose matrix:
# [[-0.35577736  0.51761418  0.77813754  0.81217341]
#  [-0.24050633  0.7538631  -0.61143039 -2.48222519]
#  [-0.90309422 -0.4046801  -0.14371794  5.15397285]
#  [ 0.          0.          0.          1.        ]]
#
# Image 118 pose matrix:
# [[-0.30995801  0.54300714  0.78042891  0.68250125]
#  [-0.2895106   0.727967   -0.62148826 -2.51952023]
#  [-0.90559905 -0.41857771 -0.06843288  5.1507811 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 128 pose matrix:
# [[-0.25969523  0.57736023  0.77408885  0.54666398]
#  [-0.33831712  0.69639411 -0.63291134 -2.53652264]
#  [-0.90448876 -0.42625156  0.01448062  5.07299079]
#  [ 0.          0.          0.          1.        ]]
#
# Image 129 pose matrix:
# [[-0.21165792  0.60668087  0.76625013  0.4758447 ]
#  [-0.39310696  0.66495178 -0.63506381 -2.54839026]
#  [-0.89480045 -0.43563454  0.09774817  4.98043063]
#  [ 0.          0.          0.          1.        ]]
#
# Image 120 pose matrix:
# [[-0.17660003  0.63020656  0.75607679  0.47797138]
#  [-0.43047435  0.64133964 -0.63511833 -2.61561873]
#  [-0.88515776 -0.43763358  0.15802716  4.92439722]
#  [ 0.          0.          0.          1.        ]]
#
# Image 121 pose matrix:
# [[-0.12748401  0.65530182  0.74453164  0.44124665]
#  [-0.48353008  0.61435049 -0.62351594 -2.65230215]
#  [-0.86599451 -0.43949176  0.23853828  4.873661  ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 131 pose matrix:
# [[-0.07407658  0.6846433   0.72510427  0.28849711]
#  [-0.5321311   0.58780184 -0.60936483 -2.61502572]
#  [-0.84341517 -0.4309902   0.32077765  4.76815211]
#  [ 0.          0.          0.          1.        ]]
#
# Image 122 pose matrix:
# [[-0.02662198  0.71284103  0.70082019  0.1087982 ]
#  [-0.57936212  0.56031534 -0.59193433 -2.65048474]
#  [-0.81463538 -0.42178713  0.39807639  4.70036412]
#  [ 0.          0.          0.          1.        ]]
#
# Image 125 pose matrix:
# [[ 0.00992284  0.73353406  0.67958025 -0.00953321]
#  [-0.61372332  0.54102103 -0.57501299 -2.65782957]
#  [-0.78945882 -0.41136849  0.45555542  4.65746371]
#  [ 0.          0.          0.          1.        ]]
#
# Image 123 pose matrix:
# [[ 0.0501481   0.76355564  0.64379185 -0.14894822]
#  [-0.66130044  0.5084419  -0.55151478 -2.67038808]
#  [-0.74844298 -0.39808242  0.53043708  4.67576986]
#  [ 0.          0.          0.          1.        ]]
#
# Image 124 pose matrix:
# [[ 0.08452101  0.78907309  0.60845694 -0.23272999]
#  [-0.7073855   0.47757808 -0.52108055 -2.64667168]
#  [-0.70175634 -0.38637137  0.59854424  4.60095106]
#  [ 0.          0.          0.          1.        ]]
#
# Image 126 pose matrix:
# [[ 0.12354612  0.81726466  0.56286306 -0.30873086]
#  [-0.7544546   0.44581459 -0.4817132  -2.57145845]
#  [-0.64461974 -0.36514082  0.67166775  4.33014528]
#  [ 0.          0.          0.          1.        ]]
#
# Image 127 pose matrix:
# [[ 0.15747231  0.83158701  0.53260259 -0.30686702]
#  [-0.77693167  0.4372436  -0.45298479 -2.54189082]
#  [-0.60957334 -0.34246326  0.71494004  4.19228176]
#  [ 0.          0.          0.          1.        ]]
#
# Image 139 pose matrix:
# [[ 0.17681637  0.84704384  0.50125113 -0.30798759]
#  [-0.80938586  0.41490871 -0.41562638 -2.58280257]
#  [-0.56002723 -0.33221603  0.75894797  4.14410863]
#  [ 0.          0.          0.          1.        ]]
#
# Image 130 pose matrix:
# [[ 0.21445718  0.86386438  0.45579212 -0.41100843]
#  [-0.84500515  0.39813812 -0.35700468 -2.56279979]
#  [-0.48987184 -0.30858447  0.81535342  4.06007411]
#  [ 0.          0.          0.          1.        ]]
#
# Image 132 pose matrix:
# [[ 0.2472622   0.8803008   0.40488505 -0.58271139]
#  [-0.87331893  0.38347994 -0.30042833 -2.51532084]
#  [-0.41973259 -0.27930921  0.86360345  4.00695661]
#  [ 0.          0.          0.          1.        ]]
#
# Image 134 pose matrix:
# [[ 0.25638646  0.89374769  0.36807749 -0.62516393]
#  [-0.88735199  0.36862511 -0.27698733 -2.54055092]
#  [-0.38323939 -0.25559849  0.88757928  4.00609174]
#  [ 0.          0.          0.          1.        ]]
#
# Image 138 pose matrix:
# [[ 0.25686059  0.91210799  0.31950218 -0.57670014]
#  [-0.9015845   0.34522023 -0.26070746 -2.52583104]
#  [-0.34809198 -0.22109274  0.9110159   4.07692796]
#  [ 0.          0.          0.          1.        ]]
#
# Image 133 pose matrix:
# [[ 0.2637359   0.92602192  0.27004958 -0.53708384]
#  [-0.91459464  0.32903142 -0.23506377 -2.47451588]
#  [-0.306529   -0.18499115  0.93371208  4.09333374]
#  [ 0.          0.          0.          1.        ]]
#
# Image 137 pose matrix:
# [[ 0.27183984  0.93852024  0.21279768 -0.52635623]
#  [-0.92912899  0.31355314 -0.19596874 -2.39488315]
#  [-0.25064401 -0.14444439  0.9572426   4.04261531]
#  [ 0.          0.          0.          1.        ]]
#
# Image 135 pose matrix:
# [[ 0.28053789  0.94510061  0.16758082 -0.55865385]
#  [-0.93916084  0.30632532 -0.15537604 -2.36063807]
#  [-0.19818024 -0.11379648  0.97353734  3.9404838 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 136 pose matrix:
# [[ 0.28732499  0.95237867  0.10207457 -0.56838168]
#  [-0.95085875  0.29644543 -0.08937415 -2.35267973]
#  [-0.11537757 -0.07137908  0.99075378  3.86517535]
#  [ 0.          0.          0.          1.        ]]
#
# Image 142 pose matrix:
# [[ 0.28369296  0.9585248   0.02735885 -0.55997682]
#  [-0.95877828  0.28401906 -0.00879631 -2.34386038]
#  [-0.01620192 -0.02373562  0.99958697  3.76317898]
#  [ 0.          0.          0.          1.        ]]
#
# Image 147 pose matrix:
# [[ 0.27900356  0.95924536 -0.04478124 -0.68047484]
#  [-0.95773758  0.28135705  0.05980743 -2.25592055]
#  [ 0.06996951  0.0262022   0.99720495  3.71020567]
#  [ 0.          0.          0.          1.        ]]
#
# Image 140 pose matrix:
# [[ 0.27111906  0.95670906 -0.10584062 -0.79344045]
#  [-0.95336228  0.28205711  0.1074437  -2.13308041]
#  [ 0.13264546  0.07177442  0.98856139  3.6424458 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 148 pose matrix:
# [[ 0.24574313  0.94999614 -0.19265942 -0.92079498]
#  [-0.94545354  0.27875316  0.16856537 -2.06186795]
#  [ 0.21384087  0.14072675  0.96667888  3.45033887]
#  [ 0.          0.          0.          1.        ]]
#
# Image 145 pose matrix:
# [[ 0.22598021  0.93473527 -0.2742315  -1.05293072]
#  [-0.93036472  0.290533    0.22363379 -1.8980739 ]
#  [ 0.28871169  0.2045985   0.93529942  3.34781873]
#  [ 0.          0.          0.          1.        ]]
#
# Image 141 pose matrix:
# [[ 0.18149557  0.91684151 -0.35561356 -1.11580752]
#  [-0.91135434  0.29267376  0.28943968 -1.76795881]
#  [ 0.36944908  0.27155795  0.88868648  3.18702148]
#  [ 0.          0.          0.          1.        ]]
#
# Image 146 pose matrix:
# [[ 0.14831651  0.90317353 -0.40283965 -1.12058019]
#  [-0.89014512  0.29939505  0.34351749 -1.71851332]
#  [ 0.4308641   0.30763644  0.84836074  3.0343345 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 143 pose matrix:
# [[ 0.09296881  0.87957275 -0.46659251 -1.05099466]
#  [-0.85025306  0.31398251  0.42247451 -1.56154831]
#  [ 0.51809896  0.35744476  0.77705001  2.66836573]
#  [ 0.          0.          0.          1.        ]]
#
# Image 144 pose matrix:
# [[ 0.04439428  0.85583205 -0.51534518 -0.87487244]
#  [-0.81658477  0.32826162  0.47479851 -1.51254489]
#  [ 0.57551583  0.39974468  0.71343235  2.43007438]
#  [ 0.          0.          0.          1.        ]]
#
# Image 150 pose matrix:
# [[-0.00674727  0.8285014  -0.55994634 -0.77842014]
#  [-0.77147439  0.35195502  0.53005182 -1.46484949]
#  [ 0.6362246   0.43556067  0.63679287  2.28659265]
#  [ 0.          0.          0.          1.        ]]
#
# Image 149 pose matrix:
# [[-0.04700542  0.80639388 -0.58950776 -0.73301636]
#  [-0.73758373  0.36996224  0.56488776 -1.36251134]
#  [ 0.67361765  0.46136412  0.57739278  2.16819961]
#  [ 0.          0.          0.          1.        ]]
#
# Image 152 pose matrix:
# [[-0.10706757  0.77254457 -0.62586854 -0.63011974]
#  [-0.68982083  0.39561092  0.60633261 -1.34270761]
#  [ 0.71601939  0.49665571  0.49056023  2.10431157]
#  [ 0.          0.          0.          1.        ]]
#
# Image 151 pose matrix:
# [[-0.16495062  0.73442003 -0.65834528 -0.55778522]
#  [-0.6397983   0.42832248  0.63812067 -1.36568861]
#  [ 0.75063268  0.52646659  0.39922863  2.05822405]
#  [ 0.          0.          0.          1.        ]]
#
# Image 153 pose matrix:
# [[-0.23002764  0.6932921  -0.68295925 -0.50530414]
#  [-0.59077159  0.45819968  0.66410992 -1.37700958]
#  [ 0.77335387  0.55623656  0.30417869  2.07235506]
#  [ 0.          0.          0.          1.        ]]
#
# Image 158 pose matrix:
# [[-0.2776764   0.6638285  -0.69442605 -0.44537209]
#  [-0.55230636  0.48113548  0.68078362 -1.39802828]
#  [ 0.78603658  0.57257347  0.23303674  2.06250915]
#  [ 0.          0.          0.          1.        ]]
#
# Image 154 pose matrix:
# [[-0.3368024   0.62741049 -0.70208277 -0.29949538]
#  [-0.49927468  0.51318557  0.69811558 -1.3903484 ]
#  [ 0.79830378  0.58565916  0.14040804  2.01731312]
#  [ 0.          0.          0.          1.        ]]
#
# Image 155 pose matrix:
# [[-0.38589313  0.59975723 -0.70098343 -0.15408344]
#  [-0.44828467  0.54219434  0.71068006 -1.38164087]
#  [ 0.80630475  0.58848668  0.0596329   2.03115888]
#  [ 0.          0.          0.          1.        ]]
#
# Image 156 pose matrix:
# [[-0.43629395  0.57246356 -0.69421399 -0.13734479]
#  [-0.3969676   0.56991917  0.71945038 -1.29413068]
#  [ 0.80750499  0.58947232 -0.0214028   2.12134495]
#  [ 0.          0.          0.          1.        ]]
#
# Image 157 pose matrix:
# [[-0.46691253  0.55732992 -0.68656832 -0.19151556]
#  [-0.36018923  0.5892114   0.72325213 -1.22534891]
#  [ 0.80762393  0.58498999 -0.07436595  2.18983025]
#  [ 0.          0.          0.          1.        ]]
#
# Image 161 pose matrix:
# [[-0.50689215  0.53666259 -0.67457662 -0.24592186]
#  [-0.31463276  0.61338696  0.72440504 -1.18568966]
#  [ 0.80253759  0.57943913 -0.1420694   2.21510428]
#  [ 0.          0.          0.          1.        ]]
#
# Image 163 pose matrix:
# [[-0.54083394  0.52155717 -0.65990664 -0.28919693]
#  [-0.26826645  0.63661989  0.72301329 -1.28181076]
#  [ 0.79720246  0.56806094 -0.20438936  2.27044699]
#  [ 0.          0.          0.          1.        ]]
#
# Image 159 pose matrix:
# [[-0.56705937  0.51054286 -0.6463665  -0.29567022]
#  [-0.22638762  0.65790572  0.71826786 -1.38614306]
#  [ 0.79195474  0.55362989 -0.25749102  2.35396631]
#  [ 0.          0.          0.          1.        ]]
#
# Image 160 pose matrix:
# [[-0.58199839  0.50379105 -0.63833569 -0.22863162]
#  [-0.19717441  0.67412708  0.71181102 -1.51372462]
#  [ 0.78892339  0.54013633 -0.29300618  2.37233454]
#  [ 0.          0.          0.          1.        ]]
#
# Image 162 pose matrix:
# [[-0.59201943  0.50044637 -0.63171704 -0.07902944]
#  [-0.16312743  0.69320709  0.70203517 -1.77387809]
#  [ 0.78924168  0.51866884 -0.32875554  2.32622172]
#  [ 0.          0.          0.          1.        ]]
#
# Image 165 pose matrix:
# [[-0.6007628   0.49849588 -0.62496873  0.07697771]
#  [-0.12954703  0.71073121  0.69143237 -2.05216964]
#  [ 0.78886097  0.49634969 -0.36240221  2.3297747 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 164 pose matrix:
# [[-0.60025291  0.50389749 -0.62111494  0.18006616]
#  [-0.0931573   0.72724493  0.68002686 -2.27435961]
#  [ 0.79436652  0.46604949 -0.38958915  2.10186181]
#  [ 0.          0.          0.          1.        ]]
#
# Image 166 pose matrix:
# [[-0.59629791  0.5120457  -0.618254    0.23139281]
#  [-0.06920082  0.73450299  0.67506785 -2.40717565]
#  [ 0.799775    0.44532523 -0.40254862  2.01720339]
#  [ 0.          0.          0.          1.        ]]
#
# Image 167 pose matrix:
# [[-0.58934617  0.5259357  -0.61323954  0.23272583]
#  [-0.03174192  0.74341139  0.6680808  -2.52193989]
#  [ 0.8072568   0.41319626 -0.42143245  1.99385351]
#  [ 0.          0.          0.          1.        ]]
#
# Image 168 pose matrix:
# [[-0.58277956  0.53753001 -0.60945014  0.21813529]
#  [ 0.00263668  0.75121904  0.66004773 -2.58889384]
#  [ 0.81262601  0.3830554  -0.4392124   2.09785126]
#  [ 0.          0.          0.          1.        ]]
#
# Image 169 pose matrix:
# [[-0.57434592  0.55382526 -0.60283028  0.27330736]
#  [ 0.04280901  0.75571716  0.65349748 -2.65617556]
#  [ 0.8174926   0.34952704 -0.45775178  2.10265835]
#  [ 0.          0.          0.          1.        ]]
#
# Image 171 pose matrix:
# [[-0.55510281  0.57002082 -0.60575336  0.32370636]
#  [ 0.06149079  0.75438984  0.65354025 -2.67869182]
#  [ 0.82950573  0.32553377 -0.45381494  2.26628846]
#  [ 0.          0.          0.          1.        ]]
#
# Image 170 pose matrix:
# [[-0.50490381  0.58928073 -0.63073003  0.50912085]
#  [ 0.05696187  0.75186264  0.65685456 -2.66278991]
#  [ 0.86129408  0.29572081 -0.41318484  2.38288443]
#  [ 0.          0.          0.          1.        ]]
#
# Image 173 pose matrix:
# [[-0.45946962  0.60799494 -0.6474796   0.66852276]
#  [ 0.06137268  0.74897532  0.65974947 -2.65167003]
#  [ 0.88607058  0.26339728 -0.38144568  2.62751004]
#  [ 0.          0.          0.          1.        ]]
#
# Image 175 pose matrix:
# [[-0.43415507  0.622053   -0.65158226  0.75100601]
#  [ 0.07852802  0.7466871   0.66052383 -2.6033965 ]
#  [ 0.8974089   0.2356023  -0.37302658  2.84327741]
#  [ 0.          0.          0.          1.        ]]
#
# Image 174 pose matrix:
# [[-0.42436834  0.63003272 -0.65036165  0.80069363]
#  [ 0.09178645  0.74447424  0.66131185 -2.56170515]
#  [ 0.9008256   0.22094542 -0.37375977  2.87503222]
#  [ 0.          0.          0.          1.        ]]
#
# Image 172 pose matrix:
# [[-0.41453448  0.63831348 -0.64862706  0.82022834]
#  [ 0.10280298  0.74103447  0.66355065 -2.52890425]
#  [ 0.90420834  0.20838383 -0.37280486  2.97192682]
#  [ 0.          0.          0.          1.        ]]
#
# Image 177 pose matrix:
# [[-0.41153905  0.64214168 -0.64675318  0.78247862]
#  [ 0.11212534  0.73991401  0.66329116 -2.50689619]
#  [ 0.90446864  0.20045279 -0.37650386  2.98430237]
#  [ 0.          0.          0.          1.        ]]
#
# Image 176 pose matrix:
# [[-0.40578335  0.64553052 -0.6470164   0.78671412]
#  [ 0.11872469  0.73915069  0.66299374 -2.48590149]
#  [ 0.90622532  0.192215   -0.37657545  3.01632386]
#  [ 0.          0.          0.          1.        ]]
#
# Image 181 pose matrix:
# [[-0.40365935  0.64729143 -0.6465856   0.78155726]
#  [ 0.12406965  0.73892051  0.66227124 -2.47886416]
#  [ 0.90645786  0.18711033 -0.37858139  3.04031829]
#  [ 0.          0.          0.          1.        ]]
#
# Image 180 pose matrix:
# [[-0.4048129   0.64827077 -0.64488102  0.76368687]
#  [ 0.12880212  0.73864524  0.66167456 -2.45649734]
#  [ 0.90528257  0.18479235 -0.38251177  3.01350659]
#  [ 0.          0.          0.          1.        ]]
#
# Image 178 pose matrix:
# [[-0.40869815  0.64702882 -0.64367657  0.74568394]
#  [ 0.13051732  0.739454    0.66043395 -2.46897168]
#  [ 0.90328902  0.1859072  -0.38666195  3.02297853]
#  [ 0.          0.          0.          1.        ]]
#
# Image 179 pose matrix:
# [[-0.41029595  0.64698393 -0.64270447  0.73462795]
#  [ 0.13169176  0.73940405  0.66025672 -2.49374406]
#  [ 0.90239377  0.18626178 -0.38857694  2.98124917]
#  [ 0.          0.          0.          1.        ]]
#
# Image 182 pose matrix:
# [[-0.41116558  0.64697517 -0.6421573   0.74502727]
#  [ 0.1332065   0.73954116  0.65979914 -2.4857636 ]
#  [ 0.90177541  0.18574717 -0.39025517  2.9891932 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 183 pose matrix:
# [[-0.41222591  0.64620281 -0.64225519  0.73655439]
#  [ 0.13408484  0.74029078  0.65877979 -2.44524764]
#  [ 0.90116095  0.18544941 -0.39181304  2.94828988]
#  [ 0.          0.          0.          1.        ]]
#
# Image 184 pose matrix:
# [[-0.41354392  0.64635605 -0.6412529   0.70097728]
#  [ 0.13703739  0.74046202  0.65797929 -2.43117178]
#  [ 0.90011232  0.18422771 -0.39478851  2.9116682 ]
#  [ 0.          0.          0.          1.        ]]
#
# Image 187 pose matrix:
# [[-0.41754241  0.64491896 -0.6401077   0.66459504]
#  [ 0.13997212  0.74169677  0.65596776 -2.4232466 ]
#  [ 0.89781186  0.18429713 -0.39996053  2.88946805]
#  [ 0.          0.          0.          1.        ]]
#
# Image 185 pose matrix:
# [[-0.42073216  0.64342802 -0.63951923  0.64243073]
#  [ 0.14217424  0.74300463  0.65401117 -2.40753859]
#  [ 0.89597485  0.18424037 -0.40408483  2.89193032]
#  [ 0.          0.          0.          1.        ]]
#
# Image 186 pose matrix:
# [[-0.42379133  0.64152874 -0.63940736  0.62409342]
#  [ 0.1436964   0.74461416  0.65184438 -2.38457218]
#  [ 0.89428868  0.18436546 -0.4077464   2.85732149]
#  [ 0.          0.          0.          1.        ]]
#
# Image 188 pose matrix:
# [[-0.42356436  0.64005867 -0.64102896  0.60018582]
#  [ 0.14248812  0.74590813  0.65062908 -2.37717147]
#  [ 0.8945895   0.18424428 -0.40714085  2.85084451]
#  [ 0.          0.          0.          1.        ]]
#
# Image 189 pose matrix:
# [[-0.42758929  0.63706086 -0.64134301  0.58169954]
#  [ 0.14224436  0.7480496   0.64821936 -2.38622402]
#  [ 0.89271157  0.18594423 -0.41047631  2.84007511]
#  [ 0.          0.          0.          1.        ]]
#
# Image 190 pose matrix:
# [[-0.42764173  0.63546002 -0.64289432  0.58129179]
#  [ 0.14013268  0.7492128   0.64733532 -2.3917673 ]
#  [ 0.89302037  0.18673709 -0.40944337  2.83150398]
#  [ 0.          0.          0.          1.        ]]
#
# Image 191 pose matrix:
# [[-0.42763786  0.63448223 -0.64386191  0.6051524 ]
#  [ 0.14023767  0.75021843  0.64614681 -2.38487295]
#  [ 0.89300574  0.18602314 -0.40980012  2.86778102]
#  [ 0.          0.          0.          1.        ]]
#
# Image 193 pose matrix:
# [[-0.4299596   0.63130334 -0.64543848  0.6075808 ]
#  [ 0.13511315  0.75183279  0.64536183 -2.39390063]
#  [ 0.8926809   0.19027229 -0.40855511  2.82654446]
#  [ 0.          0.          0.          1.        ]]
#
# Image 192 pose matrix:
# [[-0.43011299  0.6307572  -0.64587009  0.60568274]
#  [ 0.13269219  0.75182765  0.64586993 -2.41524479]
#  [ 0.8929701   0.19209514 -0.40706739  2.80420951]
#  [ 0.          0.          0.          1.        ]]

# %%
# 이미지 리스트 → NumPy 배열 변환 (dtype 명확히 지정)
images = np.stack(image_list, axis=0)  # np.array() 대신 np.stack() 사용
poses = np.stack(pose_list, axis=0)    # 포즈도 같은 방식으로 변환

print(f"Images Shape: {images.shape}, Poses Shape: {poses.shape}")
# Out:
# Images Shape: (193, 720, 720, 3), Poses Shape: (193, 4, 4)

# %%
# 4️⃣ 특정 테스트 이미지 및 포즈 선택 (101번째 이미지)
# 🔹 테스트 이미지 및 포즈 선택 (101번째 이미지 사용 가능)
testimg, testpose = images[101], poses[101]

# 🔹 NeRF 학습용으로 사용할 이미지 개수 설정 (100개로 제한하지 않음)
train_images = images  # 193개 이미지 전부 사용
train_poses = poses  # 193개 포즈 전부 사용

# 🔹 테스트 이미지 출력
plt.imshow(testimg)
plt.title("Test Image (101st)")
plt.show()

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, L_embed=6):
        super(PositionalEncoding, self).__init__()
        self.L_embed = L_embed

    def forward(self, x):
        if self.L_embed == 0:
            return x  # 위치 인코딩 없이 원본 값 사용

        rets = [x]
        for i in range(self.L_embed):
            for fn in [torch.sin, torch.cos]:
                encoded = fn(2.0**i * x)
                #print(f"🔥 PositionalEncoding Debug: i={i}, fn={fn.__name__}, encoded.shape={encoded.shape}")  # ✅ 디버깅용 출력
                rets.append(encoded)

        encoded_x = torch.cat(rets, dim=-1)

        #print(f"🔥 Final PositionalEncoding Output Shape: {encoded_x.shape}")  # ✅ 차원 확인
        return encoded_x




# 🔹 L_embed 값에 따라 위치 인코딩 활성화 여부 결정
L_embed = 6  # 위치 인코딩 활성화
# L_embed = 0  # 위치 인코딩 비활성화

embed_fn = PositionalEncoding(L_embed)  # PyTorch에서 사용

dummy_input = torch.randn(1, 3)  # 예제 입력
encoded = embed_fn(dummy_input)
print(f"🔥 Debug: Encoded shape = {encoded.shape}")  # ✅ 차원 확인

# NeRF MLP 모델
class NeRFModel(nn.Module):
    def __init__(self, D=8, W=256, L_embed=6):
        super(NeRFModel, self).__init__()
        self.L_embed = L_embed
        self.embed_fn = PositionalEncoding(L_embed)

        # ✅ 입력 차원을 위치 인코딩 크기에 맞게 설정
        self.input_dim = 3 + 3 * 2 * L_embed  # 3D 좌표 + 위치 인코딩 차원
        print(f"🔥 Debug: Model input_dim = {self.input_dim}")  # ✅ 차원 확인

        layers = []
        for i in range(D):
            if i == 0:
                layers.append(nn.Linear(self.input_dim, W))  # ✅ 첫 번째 레이어 input_dim 확인
            else:
                layers.append(nn.Linear(W, W))
            layers.append(nn.ReLU())

            if i % 4 == 0 and i > 0:  # Residual Connection
                layers.append(nn.Linear(W, W))  # ✅ Residual 부분도 수정

        layers.append(nn.Linear(W, 4))  # 마지막 출력: RGB(3) + sigma(1)
        self.model = nn.Sequential(*layers)
    def forward(self, x):
        # ✅ 입력 텐서를 모델이 있는 디바이스로 이동
        x = x.to(next(self.parameters()).device)

        x = self.embed_fn(x)

        # 🔥 Debug: 모델 입력 차원 확인
        if x.shape[-1] != self.input_dim:
            raise ValueError(f"❌ Mismatch: Model expects {self.input_dim} but got {x.shape[-1]}")

        return self.model(x)


def get_rays(H, W, focal, c2w):
    """
    H, W: 이미지 해상도
    focal: 초점 거리
    c2w: 카메라 좌표계 변환 행렬 (4x4)
    """
    # ✅ numpy.ndarray → torch.Tensor 변환 후 device로 이동
    if isinstance(c2w, np.ndarray):
        c2w = torch.tensor(c2w, dtype=torch.float32)  # numpy → torch 변환

    device = c2w.device  # ✅ 이제 오류 발생 X

    # ✅ CPU가 아닌 c2w의 디바이스에서 생성하도록 수정
    i, j = torch.meshgrid(
        torch.arange(W, dtype=torch.float32, device=device),
        torch.arange(H, dtype=torch.float32, device=device),
        indexing='xy'
    )

    # ✅ c2w의 디바이스에서 연산하도록 변경
    dirs = torch.stack([(i - W * 0.5) / focal, -(j - H * 0.5) / focal, -torch.ones_like(i, device=device)], dim=-1)

    # ✅ c2w가 GPU에 있을 경우 모든 연산이 GPU에서 수행됨
    rays_d = torch.sum(dirs[..., None, :] * c2w[:3, :3], dim=-1)
    rays_o = c2w[:3, -1].expand(rays_d.shape)

    return rays_o.to(device), rays_d.to(device)

def render_rays(network_fn, rays_o, rays_d, near, far, N_samples, rand=False):
    device = rays_o.device  # ✅ 모든 텐서가 동일한 device에 있어야 함

    def batchify(fn, chunk=1024*32):
        return lambda inputs: torch.cat([fn(inputs[i:i+chunk].to(device)) for i in range(0, inputs.shape[0], chunk)], dim=0)

    z_vals = torch.linspace(near, far, N_samples, device=device)

    if rand:
        z_vals += torch.rand_like(z_vals) * (far - near) / N_samples

    # ✅ `pts`도 `cuda`로 이동
    pts = (rays_o[..., None, :] + rays_d[..., None, :] * z_vals[..., :, None]).to(device)
    pts_flat = pts.view(-1, 3).to(device)  # ✅ 여기서 `cuda`로 이동

    #print(f"🔥 Debug: pts_flat.device = {pts_flat.device}")  # ✅ 디버깅 추가

    raw = batchify(network_fn)(pts_flat)
    raw = raw.view(list(pts.shape[:-1]) + [4])
    # return raw
    # 🔹 RGB, 밀도(Sigma) 계산
    sigma_a = F.relu(raw[..., 3])  # ✅ 볼륨 밀도 (sigma)
    rgb = torch.sigmoid(raw[..., :3])  # ✅ 색상 (RGB)

    # 🔹 깊이 및 가중치 계산
    dists = torch.cat([z_vals[..., 1:] - z_vals[..., :-1], torch.full_like(z_vals[..., :1], 1e10)], dim=-1)
    alpha = 1.0 - torch.exp(-sigma_a * dists)
    weights = alpha * torch.cumprod(torch.cat([torch.ones_like(alpha[..., :1]), 1.0 - alpha + 1e-10], dim=-1), dim=-1)[..., :-1]

    # 🔹 최종 출력값
    rgb_map = torch.sum(weights[..., None] * rgb, dim=-2)
    depth_map = torch.sum(weights * z_vals, dim=-1)
    acc_map = torch.sum(weights, dim=-1)

    return rgb_map.to(device), depth_map.to(device), acc_map.to(device)  # ✅ 3개의 값 반환
# Out:
# 🔥 Debug: Encoded shape = torch.Size([1, 39])

# %%
def train_step(model, optimizer, images, poses, H, W, focal, scaler):
    img_i = np.random.randint(images.shape[0])  # 랜덤 이미지 선택
    target = torch.tensor(images[img_i], dtype=torch.float32, device=device)
    pose = torch.tensor(poses[img_i], dtype=torch.float32, device=device)

    rays_o, rays_d = get_rays(H, W, focal, pose)

    optimizer.zero_grad(set_to_none=True)  # ✅ 기존 zero_grad()에서 메모리 할당 해제 추가

    # ✅ autocast 적용 범위를 줄이기
    with torch.amp.autocast("cuda", dtype=torch.float16):
      rgb, depth, acc = render_rays(model, rays_o, rays_d, near=2.0, far=6.0, N_samples=N_samples, rand=True)
      loss = F.mse_loss(rgb, target)

    scaler.scale(loss).backward()
    scaler.step(optimizer)
    scaler.update()

    del rays_o, rays_d, rgb, depth, acc, loss  # ✅ 메모리 정리
    torch.cuda.empty_cache()

# %%
torch.cuda.empty_cache()  # 기본적인 캐시 정리
torch.cuda.ipc_collect()  # 추가적인 메모리 정리

# 모델 초기화
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
model = NeRFModel(D=6, W=96, L_embed=6).to(device)
optimizer = optim.Adam(model.parameters(), lr=5e-4)

# Mixed Precision 사용
scaler = torch.amp.GradScaler("cuda")

def batchify(fn, chunk=512):  # ✅ 메모리 최적화
    return lambda inputs: torch.cat([fn(inputs[i:i + chunk]) for i in range(0, inputs.shape[0], chunk)], dim=0)

# 학습 파라미터
N_samples = 32
N_iters = 1000
psnrs = []
iternums = []
i_plot = 25

# 학습 시작
t = time.time()
torch.cuda.empty_cache()  # ✅ GPU 메모리 캐시 비우기

for i in range(N_iters + 1):
    train_step(model, optimizer, images, poses, H, W, focal, scaler)

    # 로그 출력 및 평가
    if i % i_plot == 0:
        print(i, (time.time() - t) / i_plot, 'secs per iter')
        t = time.time()
        with torch.no_grad():
          testpose = torch.tensor(testpose, dtype=torch.float32, device=device) if isinstance(testpose, np.ndarray) else testpose
          rays_o, rays_d = get_rays(H, W, focal, testpose)
          rays_o, rays_d = rays_o.to(device), rays_d.to(device)
          rgb, depth, acc = render_rays(model, rays_o, rays_d, near=2.0, far=6.0, N_samples=N_samples)

          test_target = torch.tensor(testimg, dtype=torch.float32, device=device)
          test_target = test_target.squeeze(-1) if test_target.shape != rgb.shape else test_target

          loss = F.mse_loss(rgb, test_target)
          psnr = -10. * torch.log10(loss)

          psnrs.append(psnr.item())
          iternums.append(i)


        # ✅ 메모리 사용량 디버깅
        print(f"🔥 GPU 메모리 사용량: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
        print(f"🔥 GPU 예약 메모리: {torch.cuda.memory_reserved() / 1e9:.2f} GB")

        # 결과 시각화
        plt.figure(figsize=(10, 4))
        plt.subplot(121)
        plt.imshow(rgb.cpu().numpy())  # GPU → CPU 변환 후 시각화
        plt.title(f'Iteration: {i}')
        plt.subplot(122)
        plt.plot(iternums, psnrs)
        plt.title('PSNR')
        plt.show()

print('Done')
# Out:
# Device: cuda
# 🔥 Debug: Model input_dim = 39
# 0 0.0546534538269043 secs per iter
# 🔥 GPU 메모리 사용량: 0.30 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 25 1.4415390396118164 secs per iter
# 🔥 GPU 메모리 사용량: 0.30 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 50 1.43524395942688 secs per iter
# 🔥 GPU 메모리 사용량: 0.30 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 75 1.4505310249328613 secs per iter
# 🔥 GPU 메모리 사용량: 0.31 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 100 1.4464593124389649 secs per iter
# 🔥 GPU 메모리 사용량: 0.30 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 125 1.441628761291504 secs per iter
# 🔥 GPU 메모리 사용량: 0.30 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 150 1.446812801361084 secs per iter
# 🔥 GPU 메모리 사용량: 0.30 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 175 1.4413839530944825 secs per iter
# 🔥 GPU 메모리 사용량: 0.30 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 200 1.440512866973877 secs per iter
# 🔥 GPU 메모리 사용량: 0.29 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 225 1.441392288208008 secs per iter
# 🔥 GPU 메모리 사용량: 0.30 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 250 1.4308302974700928 secs per iter
# 🔥 GPU 메모리 사용량: 0.29 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 275 1.4512257289886474 secs per iter
# 🔥 GPU 메모리 사용량: 0.29 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 300 1.4415375518798828 secs per iter
# 🔥 GPU 메모리 사용량: 0.29 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 325 1.4523646354675293 secs per iter
# 🔥 GPU 메모리 사용량: 0.29 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 350 1.432504529953003 secs per iter
# 🔥 GPU 메모리 사용량: 0.29 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 375 1.445122604370117 secs per iter
# 🔥 GPU 메모리 사용량: 0.30 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 400 1.4356172561645508 secs per iter
# 🔥 GPU 메모리 사용량: 0.29 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 425 1.358521203994751 secs per iter
# 🔥 GPU 메모리 사용량: 0.30 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 450 1.4378687953948974 secs per iter
# 🔥 GPU 메모리 사용량: 0.30 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 475 1.4292698097229004 secs per iter
# 🔥 GPU 메모리 사용량: 0.29 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 500 1.4466351509094237 secs per iter
# 🔥 GPU 메모리 사용량: 0.30 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 525 1.348122844696045 secs per iter
# 🔥 GPU 메모리 사용량: 0.30 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# 550 1.433036413192749 secs per iter
# 🔥 GPU 메모리 사용량: 0.29 GB
# 🔥 GPU 예약 메모리: 1.95 GB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-102-eb55ec7366e9> in <cell line: 0>()
#      26
#      27 for i in range(N_iters + 1):
# ---> 28     train_step(model, optimizer, images, poses, H, W, focal, scaler)
#      29
#      30     # 로그 출력 및 평가
#
# <ipython-input-99-d8ca7ec390fa> in train_step(model, optimizer, images, poses, H, W, focal, scaler)
#      10     # ✅ autocast 적용 범위를 줄이기
#      11     with torch.amp.autocast("cuda", dtype=torch.float16):
# ---> 12       rgb, depth, acc = render_rays(model, rays_o, rays_d, near=2.0, far=6.0, N_samples=N_samples, rand=True)
#      13       loss = F.mse_loss(rgb, target)
#      14
#
# <ipython-input-98-cf063fa76748> in render_rays(network_fn, rays_o, rays_d, near, far, N_samples, rand)
#     115     #print(f"🔥 Debug: pts_flat.device = {pts_flat.device}")  # ✅ 디버깅 추가
#     116
# --> 117     raw = batchify(network_fn)(pts_flat)
#     118     raw = raw.view(list(pts.shape[:-1]) + [4])
#     119     # return raw
#
# <ipython-input-98-cf063fa76748> in <lambda>(inputs)
#     102
#     103     def batchify(fn, chunk=1024*32):
# --> 104         return lambda inputs: torch.cat([fn(inputs[i:i+chunk].to(device)) for i in range(0, inputs.shape[0], chunk)], dim=0)
#     105
#     106     z_vals = torch.linspace(near, far, N_samples, device=device)
#
# <ipython-input-98-cf063fa76748> in <listcomp>(.0)
#     102
#     103     def batchify(fn, chunk=1024*32):
# --> 104         return lambda inputs: torch.cat([fn(inputs[i:i+chunk].to(device)) for i in range(0, inputs.shape[0], chunk)], dim=0)
#     105
#     106     z_vals = torch.linspace(near, far, N_samples, device=device)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# <ipython-input-98-cf063fa76748> in forward(self, x)
#      67             raise ValueError(f"❌ Mismatch: Model expects {self.input_dim} but got {x.shape[-1]}")
#      68
# ---> 69         return self.model(x)
#      70
#      71
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     248     def forward(self, input):
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/activation.py in forward(self, input)
#     131
#     132     def forward(self, input: Tensor) -> Tensor:
# --> 133         return F.relu(input, inplace=self.inplace)
#     134
#     135     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py in relu(input, inplace)
#    1702         result = torch.relu_(input)
#    1703     else:
# -> 1704         result = torch.relu(input)
#    1705     return result
#    1706
#
# KeyboardInterrupt:
